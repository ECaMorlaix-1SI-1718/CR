# %% [markdown]
# # La bionique

# %% [markdown]
# ##   Bete à corne

# %% [markdown]
# ![Captureeee.PNG](attachment:Captureeee.PNG)

# %% [markdown]
# ## Diagramme Pieuvre

# %% [markdown]
# ![Capturefff.PNG](attachment:Capturefff.PNG)

# %% [markdown]
# ## Chaine Info / Chaine Energie

# %% [markdown]
# ![Captureddd.PNG](attachment:Captureddd.PNG)

# %% [markdown]
# ## Shéma cinématique

# %% [markdown]
# ![Captureaaa.PNG](attachment:Captureaaa.PNG)

# %% [markdown]
# ![Capturebbb.PNG](attachment:Capturebbb.PNG)

# %% [markdown]
# ## Modélisation 3D

# %% [markdown]
# ![Captureggg.PNG](attachment:Captureggg.PNG)

# %% [markdown]
# ## Programme / Expérimentation

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)
